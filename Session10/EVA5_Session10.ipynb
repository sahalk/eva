# %%
# Clone the existing GitHub to extract the required Py files.
# !git clone "https://github.com/sahalk/eva.git"
# Out:
# Cloning into 'eva'...
# remote: Enumerating objects: 238, done.
# remote: Counting objects: 100% (238/238), done.
# remote: Compressing objects: 100% (181/181), done.
# remote: Total 238 (delta 125), reused 160 (delta 53), pack-reused 0
# Receiving objects: 100% (238/238), 1.87 MiB | 27.78 MiB/s, done.
# Resolving deltas: 100% (125/125), done.

# %%
# Importing the required module.

from eva.Session9.model import ResNet
from eva.Session9.loader import Loader
from eva.Session9.grad_cam import GradCam

# %%
# Mean and Std deviation of the dataset.
data_mean = (0.4914, 0.4822, 0.4465)
data_std_dev = (0.2470, 0.2435, 0.2616)

# Loading the dataset.
cifar = Loader(data_mean, data_std_dev)
# Out:
# ...
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
# Displaying the images.
cifar.disp_image(cifar.trainloader)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
#   dog truck   dog  deer

# %%
# Summary of the model.
cifar.print_sum()
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ...
#             Conv2d-1           [-1, 64, 32, 32]           1,728
#        BatchNorm2d-2           [-1, 64, 32, 32]             128
#             Conv2d-3           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-4           [-1, 64, 32, 32]             128
#             Conv2d-5           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-6           [-1, 64, 32, 32]             128
#         BasicBlock-7           [-1, 64, 32, 32]               0
#             Conv2d-8           [-1, 64, 32, 32]          36,864
#        BatchNorm2d-9           [-1, 64, 32, 32]             128
#            Conv2d-10           [-1, 64, 32, 32]          36,864
#       BatchNorm2d-11           [-1, 64, 32, 32]             128
#        BasicBlock-12           [-1, 64, 32, 32]               0
#            Conv2d-13          [-1, 128, 16, 16]          73,728
# ...

# %%
# Training the model.

learning_rate = 0.01
momentum = 0.9
epoch = 45

cifar.train(epoch, learning_rate, learning_rate)
# Out:
#   0%|          | 0/782 [00:00<?, ?it/s]
# EPOCH: 0
# Loss=1.2809406518936157 Batch_id=781 Accuracy=45.63: 100%|██████████| 782/782 [01:10<00:00, 11.14it/s]
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 1.5550, Accuracy: 4434/10000 (44.34%)
#
# EPOCH: 1
# Loss=1.3015979528427124 Batch_id=781 Accuracy=59.90: 100%|██████████| 782/782 [01:11<00:00, 10.96it/s]
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 1.2303, Accuracy: 5897/10000 (58.97%)
#
# EPOCH: 2
# Loss=1.02797532081604 Batch_id=781 Accuracy=67.31: 100%|██████████| 782/782 [01:11<00:00, 10.90it/s]
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 1.0488, Accuracy: 6405/10000 (64.05%)
#
# EPOCH: 3
# Loss=0.5386001467704773 Batch_id=781 Accuracy=72.20: 100%|██████████| 782/782 [01:11<00:00, 10.93it/s]
# ...
#   0%|          | 0/782 [00:00<?, ?it/s]
# Test set: Average loss: 0.8207, Accuracy: 7213/10000 (72.13%)
#
# EPOCH: 4
# ...

# %%
# GradCam Module.
target_layers = ['layer1.0.bn2', 'layer1.1.bn2', 'layer2.0.bn2', 'layer2.1.bn2', 'layer3.0.bn2', 'layer3.1.bn2', 'layer4.0.bn2', 'layer4.1.bn2']
grad_cam = GradCam(cifar.model, cifar.testloader, target_layers=target_layers, device=cifar.device)

# %%
# GradCam for Car.

one_hot_encoded_class = 'car' 
required_class = 'car'
overlays = grad_cam.get_overlays(required_class=required_class, one_hot_encoded_class=one_hot_encoded_class)
print("Car")
grad_cam.display_heatmaps(overlays)
# Out:
# Car

# %%
# GradCam for Truck.

one_hot_encoded_class = 'truck'
required_class = 'truck'
overlays = grad_cam.get_overlays(required_class=required_class, one_hot_encoded_class=one_hot_encoded_class)
print("Truck")
grad_cam.display_heatmaps(overlays)
# Out:
# Truck

# %%
# GradCam for Plane.

one_hot_encoded_class = 'plane'
required_class = 'plane'
overlays = grad_cam.get_overlays(required_class=required_class, one_hot_encoded_class=one_hot_encoded_class)
print("Plane")
grad_cam.display_heatmaps(overlays)
# Out:
# Plane
